# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
premier_league = pd.read_csv("premier_league.csv")
premier_league.head()
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 0  Manchester United    28       5     83              60               1
# 1            Chelsea    24       3     64              62               4
# 2          Liverpool    20      10     57              44               0
# 3            Arsenal    19       8     63              59               3
# 4  Tottenham Hotspur    17      12     57              48               3
#
#    total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0                698                   256            21           12  ...
# 1                636                   216            14           16  ...
# 2                668                   214            15            8  ...
# 3                638                   226            19           10  ...
# 4                520                   184             6            5  ...
#
# ...

# %%
city_data = premier_league[premier_league.team == "Manchester City"]

# %%
city_data
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 13   Manchester City    11      18     29              59               4
# 28   Manchester City    15      13     45              50               4
# 46   Manchester City    15      18     58              49               4
# 65   Manchester City    18       7     73              49               2
# 82   Manchester City    21       9     60              71               5
# 100  Manchester City    28       5     93              51               5
# 121  Manchester City    23       6     66              62               3
# 140  Manchester City    27       6    102              72               1
# 161  Manchester City    24       7     83              77               2
# 182  Manchester City    19      10     71              61               0
# 203  Manchester City    23       6     80              71               4
# 220  Manchester City    32       2    106              59               2
#
# ...

# %%
plt.figure(figsize=(15,8))
plt.title("Broj golova Man City-ja u sezonama 2006-2018",fontdict={"fontweight":"bold"})
plt.xlabel("Sezona")
plt.ylabel("Broj golova")
plt.grid(True)
plt.plot(city_data.season,city_data.goals,marker = "o")
plt.xticks(rotation=60)
plt.savefig("Broj golova Man City-ja u sezonama 2006-2018",dpi=300)
plt.show()
